# %% [markdown]
# # **Advanced EDA and Data Visualizations**
# ---
#
# ### **Description**
# In this notebook, you will sharpen your skills in data manipulation, exploration, and visualization using Python's pandas, matplotlib, and seaborn libraries. You'll practice filtering, grouping, and summarizing data, and learn how to create more advanced visualizations — including correlation heatmaps, group summary heatmaps, missing values heatmaps, and time series plots — to uncover patterns, trends, and insights in real-world-style datasets.
#
# <br>
#
# ### **Lab Structure**
# * **Part 1**: [Advanced EDA Commands](#p1)
#
# * **Part 2**: [Independent Practice](#p2)
#
# * **Part 3**: [Improving Visualizations Review](#p3)
#
# * **Part 4**: [Heatmaps](#p4)
#
# * **Part 5**: [Time Series Plots](#p5)
#
# <br>
#
#
#
# **Before starting, run the code below to import all necessary functions and libraries.**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <a name="p1"></a>
#
# ---
# ## **Part 1: Advanced EDA Commands**
# ---

# %% [markdown]
# #### **Problem #1.1**
# This dataset contains medical information from patients who underwent tests to evaluate their heart health. The goal is to determine whether a patient is likely to have heart disease based on various health indicators.
#
# Each row in the dataset represents one patient, and the columns include clinical and diagnostic information such as age, sex, blood pressure, cholesterol levels, and results from heart-related tests.
#
# The target column is the key variable we want to predict:
#
# * 1 = Patient has heart disease
#
# * 0 = Patient does not have heart disease
#
#
# Here is a description of each column:
#
# • `age`: Age of the patient (in years)
#
# • `sex`: Sex of the patient
#   - 0 = female
#   - 1 = male
#
# • `cp`: Chest pain type
#   - 0 = typical angina
#   - 1 = atypical angina
#   - 2 = non-anginal pain
#   - 3 = asymptomatic
#
# • `trestbps`: Resting blood pressure (in mm Hg)
#
# • `chol`: Serum cholesterol level (in mg/dl)
#
# • `fbs`: Fasting blood sugar > 120 mg/dl
#   - 1 = true
#   - 0 = false
#
# • `restecg`: Resting electrocardiographic results
#   - 0 = normal
#   - 1 = ST-T wave abnormality
#   - 2 = left ventricular hypertrophy
#
# • `thalach`: Maximum heart rate achieved
#
# • `exang`: Exercise-induced angina
#   - 1 = yes
#   - 0 = no
#
# • `oldpeak`: ST depression induced by exercise relative to rest
#
# • `slope`: Slope of the peak exercise ST segment
#   - 0 = upsloping
#   - 1 = flat
#   - 2 = downsloping
#
# • `ca`: Number of major vessels (0–3) colored by fluoroscopy
#
# • `thal`: Thalassemia
#   - 1 = normal
#   - 2 = fixed defect
#   - 3 = reversible defect
#
# • `target`: Presence of heart disease
#   - 1 = has disease
#   - 0 = no disease
#
# <br>
#
# **Run the code cell below to load the data.**

# %%
url = 'https://raw.githubusercontent.com/the-codingschool/TRAIN-datasets/refs/heads/main/heartdisease/heart.csv'
df = pd.read_csv(url)
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# #### **Problem #1.2**
#
# Which patients have a cholesterol level above 300?

# %%
df[df['chol'] > 300]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 4     57    0   0       120   354    0        1      163      1      0.6
# 16    58    0   2       120   340    0        1      172      0      0.0
# 25    71    0   1       160   302    0        1      162      0      0.4
# 28    65    0   2       140   417    1        0      157      0      0.8
# 36    54    0   2       135   304    1        1      170      0      0.0
# 39    65    0   2       160   360    0        0      151      0      0.8
# 40    51    0   2       140   308    0        0      142      0      1.5
# 44    39    1   2       140   321    0        0      182      0      0.0
# 45    52    1   1       120   325    0        1      172      0      0.2
# 51    66    1   0       120   302    0        0      151      0      0.4
# 59    57    0   0       128   303    0        0      159      0      0.0
# 61    54    1   1       108   309    0        1      156      0      0.0
# ...

# %% [markdown]
# ##### **Solution**

# %%
df[df['chol'] > 300]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 4     57    0   0       120   354    0        1      163      1      0.6
# 16    58    0   2       120   340    0        1      172      0      0.0
# 25    71    0   1       160   302    0        1      162      0      0.4
# 28    65    0   2       140   417    1        0      157      0      0.8
# 36    54    0   2       135   304    1        1      170      0      0.0
# 39    65    0   2       160   360    0        0      151      0      0.8
# 40    51    0   2       140   308    0        0      142      0      1.5
# 44    39    1   2       140   321    0        0      182      0      0.0
# 45    52    1   1       120   325    0        1      172      0      0.2
# 51    66    1   0       120   302    0        0      151      0      0.4
# 59    57    0   0       128   303    0        0      159      0      0.0
# 61    54    1   1       108   309    0        1      156      0      0.0
# ...

# %% [markdown]
# #### **Problem #1.3**
#
# Use .query() to find patients who are female and have chest pain type 2.

# %%
df.query("sex == 0 and cp == 2")
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 11    48    0   2       130   275    0        1      139      0      0.2
# 15    50    0   2       120   219    0        1      158      0      1.6
# 16    58    0   2       120   340    0        1      172      0      0.0
# 28    65    0   2       140   417    1        0      157      0      0.8
# 35    46    0   2       142   177    0        0      160      1      1.4
# 36    54    0   2       135   304    1        1      170      0      0.0
# 38    65    0   2       155   269    0        1      148      0      0.8
# 39    65    0   2       160   360    0        0      151      0      0.8
# 40    51    0   2       140   308    0        0      142      0      1.5
# 48    53    0   2       128   216    0        0      115      0      0.0
# 50    51    0   2       130   256    0        0      149      0      0.5
# 53    44    0   2       108   141    0        1      175      0      0.6
# ...

# %% [markdown]
# ##### **Solution**

# %%
df.query("sex == 0 and cp == 2")
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 11    48    0   2       130   275    0        1      139      0      0.2
# 15    50    0   2       120   219    0        1      158      0      1.6
# 16    58    0   2       120   340    0        1      172      0      0.0
# 28    65    0   2       140   417    1        0      157      0      0.8
# 35    46    0   2       142   177    0        0      160      1      1.4
# 36    54    0   2       135   304    1        1      170      0      0.0
# 38    65    0   2       155   269    0        1      148      0      0.8
# 39    65    0   2       160   360    0        0      151      0      0.8
# 40    51    0   2       140   308    0        0      142      0      1.5
# 48    53    0   2       128   216    0        0      115      0      0.0
# 50    51    0   2       130   256    0        0      149      0      0.5
# 53    44    0   2       108   141    0        1      175      0      0.6
# ...

# %% [markdown]
# #### **Problem #1.4**
# Combine conditions to find male patients older than 50 with resting BP over 140.

# %%
df[(df['sex'] == 1) & (df['age'] > 50) & (df['trestbps'] > 140)]

# %% [markdown]
# ##### **Solution**

# %%
df[(df['sex'] == 1) & (df['age'] > 50) & (df['trestbps'] > 140)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 23    61    1   2       150   243    1        1      137      1      1.0
# 26    59    1   2       150   212    1        1      157      0      1.6
# 37    54    1   2       150   232    0        0      165      0      1.6
# 83    52    1   3       152   298    1        1      178      0      1.2
# 95    53    1   0       142   226    0        0      111      1      0.0
# 101   59    1   3       178   270    0        0      145      0      4.2
# 106   69    1   3       160   234    1        0      131      0      0.1
# 111   57    1   2       150   126    1        1      173      0      0.2
# 145   70    1   1       156   245    0        0      143      0      0.0
# ...

# %% [markdown]
# #### **Problem #1.5**
#
# Show the patients sorted by their maximum heart rate, from highest to lowest.

# %%
df.sort_values(by='thalach', ascending=False)

# %% [markdown]
# #####**Solution**

# %%
df.sort_values(by='thalach', ascending=False)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 72    29    1   1       130   204    0        0      202      0      0.0
# 248   54    1   1       192   283    0        0      195      0      0.0
# 103   42    1   2       120   240    1        1      194      0      0.8
# 125   34    0   1       118   210    0        1      192      0      0.7
# 62    52    1   3       118   186    0        0      190      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 233   64    1   0       120   246    0        0       96      1      2.2
# 262   53    1   0       123   282    0        1       95      1      2.0
# 297   59    1   0       164   176    1        0       90      0      1.0
# 243   57    1   0       152   274    0        1       88      1      1.2
# 272   67    1   0       120   237    0        1       71      0      1.0
#
#      slope  ca  thal  target
# 72       2   0     2       1
# 248      2   1     3       0
# ...

# %% [markdown]
# #### **Problem #1.6**
#
# What is the average age and cholesterol level for male vs. female patients?

# %%
df.groupby('sex').agg({'age': 'mean', 'chol': 'mean'})

# %% [markdown]
# ##### **Solution**

# %%
df.groupby('sex').agg({'age': 'mean', 'chol': 'mean'})
# Out:
#            age        chol
# sex
# 0    55.677083  261.302083
# 1    53.758454  239.289855

# %% [markdown]
# #### **Problem #1.7**
#
# Create a pivot table showing average cholesterol by chest pain type (`cp`) and `sex`.

# %%
df.pivot_table(values='chol', index='cp', columns='sex', aggfunc='mean')
# Out:
# 790

# %% [markdown]
# ##### **Solution**

# %%
df.pivot_table(values='chol', index='cp', columns='sex', aggfunc='mean')
# Out:
# sex           0           1
# cp
# 0    267.538462  243.605769
# 1    251.444444  241.031250
# 2    261.057143  231.134615
# 3    247.000000  235.052632

# %% [markdown]
# <a name="p2"></a>
#
# ---
# ## **Part 2: Independent Practice**
# ---

# %% [markdown]
# #### **Problem #2.1**
# This dataset contains hourly weather observations recorded over a period of time. Each row represents the weather conditions at a specific hour of the day. The data includes temperature, humidity, wind, visibility, pressure, and textual weather summaries.
#
# * `Formatted Date`: timestamp
#
# * `Summary`: short weather description
#
# * `Precip Type`: type of precipitation (e.g. rain, snow)
#
# * `Temperature (C)`
#
# * `Apparent Temperature (C)`
#
# * `Humidity`
#
# * `Wind Speed (km/h)`
#
# * `Wind Bearing (degrees)`
#
# * `Visibility (km)`
#
# * `Loud Cover`
#
# * `Pressure (millibars)`
#
# * `Daily Summary`
#
# **Run the code cell below to load the data.**

# %%
url = 'https://raw.githubusercontent.com/the-codingschool/TRAIN-datasets/refs/heads/main/weather_history/weatherHistory.csv'
df = pd.read_csv(url)
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# #### **Problem #2.2**
#
# What are the weather conditions when the temperature was above 15°C?

# %%
df[df['Temperature (C)'] > 15]

# %% [markdown]
# ##### **Solution**

# %%
df[df['Temperature (C)'] > 15]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 10     2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain
# 11     2006-04-01 11:00:00.000 +0200  Partly Cloudy        rain
# 12     2006-04-01 12:00:00.000 +0200  Partly Cloudy        rain
# 13     2006-04-01 13:00:00.000 +0200  Partly Cloudy        rain
# 14     2006-04-01 14:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 10           16.016667                 16.016667      0.67            17.5651
# ...

# %% [markdown]
# #### **Problem #2.3**
#
# Use .query() to find rainy hours with visibility below 10 km

# %%
df.query("`Precip Type` == 'rain' and `Visibility (km)` < 10")

# %% [markdown]
# ##### **Solution**

# %%
df.query("`Precip Type` == 'rain' and `Visibility (km)` < 10")
# Out:
#                       Formatted Date        Summary Precip Type  \
# 6      2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain
# 7      2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain
# 8      2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain
# 9      2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain
# 21     2006-04-01 21:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96370  2016-09-06 13:00:00.000 +0200  Mostly Cloudy        rain
# 96372  2016-09-06 15:00:00.000 +0200  Mostly Cloudy        rain
# 96373  2016-09-06 16:00:00.000 +0200  Mostly Cloudy        rain
# 96375  2016-09-06 18:00:00.000 +0200  Mostly Cloudy        rain
# 96376  2016-09-06 19:00:00.000 +0200  Mostly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 6             7.733333                  5.522222      0.95            12.3648
# ...

# %% [markdown]
# #### **Problem #2.4**
# Find hours where the humidity was over 0.8 and wind speed was above 15 km/h

# %%
df[(df['Humidity'] > 0.8) & (df['Wind Speed (km/h)'] > 15)]

# %% [markdown]
# ##### **Solution**

# %%
df[(df['Humidity'] > 0.8) & (df['Wind Speed (km/h)'] > 15)]
# Out:
#                       Formatted Date              Summary Precip Type  \
# 50     2006-04-11 02:00:00.000 +0200             Overcast        rain
# 64     2006-04-11 16:00:00.000 +0200        Mostly Cloudy        rain
# 65     2006-04-11 17:00:00.000 +0200             Overcast        rain
# 66     2006-04-11 18:00:00.000 +0200                Foggy        rain
# 67     2006-04-11 19:00:00.000 +0200                Foggy        rain
# ...                              ...                  ...         ...
# 96343  2016-09-05 10:00:00.000 +0200  Breezy and Overcast        rain
# 96344  2016-09-05 11:00:00.000 +0200             Overcast        rain
# 96345  2016-09-05 12:00:00.000 +0200             Overcast        rain
# 96346  2016-09-05 13:00:00.000 +0200             Overcast        rain
# 96347  2016-09-05 14:00:00.000 +0200             Overcast        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %% [markdown]
# #### **Problem #2.5**
#
# Sort the dataset by pressure in descending order

# %%
df.sort_values(by='Pressure (millibars)', ascending=False)

# %% [markdown]
# #####**Solution**

# %%
df.sort_values(by='Pressure (millibars)', ascending=False)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 19952  2008-02-17 08:00:00.000 +0100          Clear        snow
# 19953  2008-02-17 09:00:00.000 +0100          Clear        snow
# 19955  2008-02-17 11:00:00.000 +0100  Partly Cloudy        snow
# 19954  2008-02-17 10:00:00.000 +0100          Clear        snow
# 19951  2008-02-17 07:00:00.000 +0100          Clear        snow
# ...                              ...            ...         ...
# 12320  2007-01-06 08:00:00.000 +0100          Clear        rain
# 12279  2007-01-04 15:00:00.000 +0100          Clear        rain
# 12546  2007-07-14 18:00:00.000 +0200          Clear        rain
# 62114  2013-08-01 02:00:00.000 +0200          Clear        rain
# 82068  2015-01-02 15:00:00.000 +0100          Clear        snow
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 19952        -8.838889                -14.627778      0.61            12.4936
# ...

# %% [markdown]
# #### **Problem #2.6**
#
# What is the average temperature and humidity for each type of precipitation?

# %%
df.groupby('Precip Type').agg({
    'Temperature (C)': 'mean',
    'Humidity': 'mean'
})
# Out:
#              Temperature (C)  Humidity
# Precip Type
# rain               13.852989  0.718699
# snow               -3.270885  0.863263

# %% [markdown]
# ##### **Solution**

# %%
df.groupby('Precip Type').agg({
    'Temperature (C)': 'mean',
    'Humidity': 'mean'
})
# Out:
#              Temperature (C)  Humidity
# Precip Type
# rain               13.852989  0.718699
# snow               -3.270885  0.863263

# %% [markdown]
# #### **Problem #2.7**
#
# Create a pivot table showing average wind speed by precipitation type and summary.

# %%
df.pivot_table(values='Wind Speed (km/h)', index='Precip Type', columns='Summary', aggfunc='mean')
# Out:
# 790

# %% [markdown]
# ##### **Solution**

# %%
df.pivot_table(values='Wind Speed (km/h)', index='Precip Type', columns='Summary', aggfunc='mean')
# Out:
# Summary         Breezy  Breezy and Dry  Breezy and Foggy  \
# Precip Type
# rain         31.947000           33.81         32.974812
# snow         32.833267             NaN         33.626937
#
# Summary      Breezy and Mostly Cloudy  Breezy and Overcast  \
# Precip Type
# rain                        33.369221            33.061248
# snow                        33.709065            32.837963
#
# Summary      Breezy and Partly Cloudy     Clear  \
# Precip Type
# rain                        33.515315  8.049318
# snow                        34.479300  8.655022
#
# Summary      Dangerously Windy and Partly Cloudy    Drizzle        Dry  ...  \
# Precip Type                                                             ...
# rain                                     63.8526  10.356428  14.713979  ...
# snow                                         NaN        NaN        NaN  ...
#
# Summary      Mostly Cloudy   Overcast  Partly Cloudy     Rain    Windy  \
# Precip Type
# ...

# %% [markdown]
# <a name="p3"></a>
#
# ---
# ## **Part 3: Improving Visualizations Review**
# ---
#
# Use the same dataset from Part 2 to complete this section.

# %% [markdown]
# #### **Problem #3.1**
#
# Plot Temperature (C) vs Humidity using a scatter plot.
# Then customize the plot by doing the following:
#
# * Make all points blue
#
# * Set the transparency (alpha) to 0.5
#
# * Add a label for the legend
#
# * Add a legend and grid
#
# * Make the title bold, in serif font.

# %%
plt.scatter(df['Temperature (C)'], df['Humidity'],
            color='blue', alpha=0.5, label='Temp vs Humidity')

plt.title('Temperature vs Humidity', fontweight='bold', family='serif')
plt.xlabel('Temperature (°C)')
plt.ylabel('Humidity')
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# ##### **Solution**

# %%
plt.scatter(df['Temperature (C)'], df['Humidity'],
            color='blue', alpha=0.5, label='Temp vs Humidity')

plt.title('Temperature vs Humidity', fontweight='bold', family='serif')
plt.xlabel('Temperature (°C)')
plt.ylabel('Humidity')
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# ####**Problem #3.2**
#
# Use the dataset to plot the average humidity by Precip Type using a bar plot.
# Then improve the visualization by:
#
# * Using a custom bar color
#
# * Adding a grid
#
# * Making the title italic and extra bold
#
# * Increasing the font size of the y-axis label

# %%
avg_humidity = df.groupby('Precip Type')['Humidity'].mean()
x = avg_humidity.index
y = avg_humidity.values

plt.bar(x, y, color='orange')
plt.title('Avg Humidity by Precip Type', fontweight='extra bold', style='italic')
plt.xlabel('Precipitation Type')
plt.ylabel('Average Humidity', fontsize='large')
plt.grid()

# %% [markdown]
# #####**Solution**

# %%
avg_humidity = df.groupby('Precip Type')['Humidity'].mean()
x = avg_humidity.index
y = avg_humidity.values


plt.bar(x, y, color='orange')
plt.title('Avg Humidity by Precip Type', fontweight='extra bold', style='italic')
plt.xlabel('Precipitation Type')
plt.ylabel('Average Humidity', fontsize='large')
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ####**Problem #3.3**
#
# Plot the change in Pressure (millibars) as the hours go by using a line plot.
# Use the first 10 rows of data only. Then improve the visualization by:
#
# * Changing the line color to green
#
# * Adding circular markers at each point
#
# * Making the line thicker
#
# * Making the title bold and serif font
#
# * Adding a y-axis label with larger font size
#
# * Adding a grid

# %%
# Use first 10 rows
x = list(range(10))  # pretend these are hours
y = df['Pressure (millibars)'].head(10)


plt.plot(x, y, color='green', marker='o', linewidth=2)
plt.title('Pressure Over First 10 Hours', fontweight='bold', family='serif')
# Out:
# Text(0.5, 1.0, 'Pressure Over First 10 Hours')

# %% [markdown]
# #####**Solution**

# %%
# Use first 10 rows
x = list(range(10))  # pretend these are hours
y = df['Pressure (millibars)'].head(10)


plt.plot(x, y, color='green', marker='o', linewidth=2)
plt.title('Pressure Over First 10 Hours', fontweight='bold', family='serif')
plt.xlabel('Hour')
plt.ylabel('Pressure (millibars)', fontsize='large')
plt.grid(True)

plt.show()

# %% [markdown]
# <a name="p4"></a>
#
# ---
# ## **Part 4: Heatmaps**
# ---

# %% [markdown]
# #### **Problem #4.1**
#
# Use the dataset below to create a correlation heatmap. Which two health metrics have the strongest positive correlation?

# %%
df = pd.DataFrame({
    'Age': [25, 30, 45, 50, 60, 70, 80],
    'Cholesterol': [180, 190, 210, 230, 250, 265, 280],
    'RestingBP': [120, 122, 130, 135, 140, 150, 160],
    'HeartRate': [80, 78, 75, 72, 70, 68, 65]
})

corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap - Health Metrics')
plt.show()

# %% [markdown]
# ##### **Solution**

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap - Health Metrics')
plt.show()

# %% [markdown]
# #### **Problem #4.2**
#
# Use the dataset below to generate a correlation heatmap. Which academic metric is most strongly correlated with final grade?

# %%
df = pd.DataFrame({
    'StudyHours': [1, 2, 3, 4, 5, 6, 7],
    'Attendance': [60, 70, 75, 80, 85, 90, 95],
    'Participation': [1, 2, 2, 3, 4, 4, 5],
    'FinalGrade': [55, 60, 65, 70, 75, 85, 90]
})

corr = df.corr()
sns.heatmap(corr, annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap - Student Performance')
plt.show()

# %% [markdown]
# ##### **Solution**

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap - Student Performance')
plt.show()

# %% [markdown]
# #### **Problem #4.3**
#
# Use the dataset below to create a heatmap showing the average hours worked by employees, grouped by Department and Day of the Week. Which department works the most hours on average on Mondays?

# %%
df = pd.DataFrame({
    'Employee': ['Alice', 'Bob', 'Alice', 'Bob', 'Charlie', 'Alice', 'Charlie', 'Bob', 'Charlie'],
    'Department': ['HR', 'HR', 'HR', 'HR', 'IT', 'HR', 'IT', 'HR', 'IT'],
    'Day': ['Monday', 'Monday', 'Tuesday', 'Tuesday', 'Monday', 'Wednesday', 'Wednesday', 'Wednesday', 'Tuesday'],
    'HoursWorked': [8, 7, 9, 6, 10, 7, 9, 8, 9]
})

# %%
pivot = df.pivot_table(values='HoursWorked', index='Day', columns='Department', aggfunc='mean')
pivot
# Out:
# Department   HR    IT
# Day
# Monday      7.5  10.0
# Tuesday     7.5   9.0
# Wednesday   7.5   9.0

# %%
sns.heatmap(pivot, annot=True, cmap='Blues')
plt.title('Average Hours Worked by Department and Day')
plt.show()

# %% [markdown]
# ##### **Solution**

# %%
# Pivot table: average hours worked by department and day
pivot = df.pivot_table(values='HoursWorked', index='Day', columns='Department', aggfunc='mean')

# Heatmap
sns.heatmap(pivot, annot=True, cmap='Blues')
plt.title('Average Hours Worked by Department and Day')
plt.show()

# %% [markdown]
# #### **Problem #4.4**
#
# Use the dataset below to generate a heatmap of average sales by Store and Product Category. Which product category had the highest average sales in Store B?

# %%
df = pd.DataFrame({
    'Store': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
    'Category': ['Food', 'Clothing', 'Electronics', 'Food', 'Clothing', 'Electronics', 'Food', 'Clothing', 'Electronics'],
    'Sales': [250, 400, 600, 300, 700, 800, 275, 650, 500]
})

# %%
df.pivot_table(values='Sales', index='Store', columns='Category', aggfunc='mean')
# Out:
# Category  Clothing  Electronics   Food
# Store
# A            400.0        600.0  250.0
# B            700.0        800.0  300.0
# C            650.0        500.0  275.0

# %%
pivot = df.pivot_table(values='Sales', index='Store', columns='Category', aggfunc='mean')
sns.heatmap(pivot, annot=True, cmap='YlOrRd')
plt.title('Average Sales by Store and Product Category')
plt.show()

# %% [markdown]
# ##### **Solution**

# %%
# Pivot table: average sales by store and category
pivot = df.pivot_table(values='Sales', index='Store', columns='Category', aggfunc='mean')

# Heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(pivot, annot=True, cmap='YlOrRd')
plt.title('Average Sales by Store and Product Category')
plt.show()

# %% [markdown]
# #### **Problem #4.5**
#
# Use the dataset below to create a missing values heatmap. Which columns have missing values, and which row has the most missing data?

# %%
df = pd.DataFrame({
    'PatientID': [101, 102, 103, 104, 105],
    'Age': [25, 30, np.nan, 45, 50],
    'BloodPressure': [120, np.nan, 130, 125, np.nan],
    'Cholesterol': [200, 190, 180, np.nan, 210],
    'Smoker': ['No', 'Yes', np.nan, 'No', 'Yes']
})

# %%
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Missing Values Heatmap - Medical Records')
plt.xlabel('Columns')
plt.ylabel('Records')
plt.show()

# %% [markdown]
# ##### **Solution**

# %%
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Missing Values Heatmap - Medical Records')
plt.xlabel('Columns')
plt.ylabel('Records')
plt.show()

# %% [markdown]
# #### **Problem #4.6**
#
# Use the dataset below to create a heatmap showing missing survey responses. Which questions were skipped the most?

# %%
df = pd.DataFrame({
    'StudentID': [1, 2, 3, 4, 5],
    'Q1_Satisfaction': [4, 5, np.nan, 3, 4],
    'Q2_Confidence': [np.nan, 3, 2, 4, np.nan],
    'Q3_Interest': [5, 4, 3, np.nan, np.nan]
})

# %%
sns.heatmap(df.isnull(), cbar=False, cmap='magma', yticklabels=False)
plt.title('Missing Values Heatmap - Student Survey')
plt.xlabel('Questions')
plt.ylabel('Students')
plt.show()

# %% [markdown]
# ##### **Solution**

# %%
sns.heatmap(df.isnull(), cbar=False, cmap='magma', yticklabels=False)
plt.title('Missing Values Heatmap - Student Survey')
plt.xlabel('Questions')
plt.ylabel('Students')
plt.show()

# %% [markdown]
# <a name="p5"></a>
#
# ---
# ## **Part 5: Time Series Plots**
# ---

# %% [markdown]
# #### **Problem #5.1**
#
# Use the dataset below to create a time series plot showing how a household’s daily water usage (in liters) changes over one week. What trend do you notice during the weekend?

# %%
df = pd.DataFrame({
    'Date': pd.date_range(start='2023-07-01', periods=7, freq='D'),
    'Water_Usage_Liters': [180, 175, 190, 200, 195, 230, 250]
})

df['Date'] = pd.to_datetime(df['Date'])
plt.plot(df['Date'], df['Water_Usage_Liters'], marker='o')
plt.title('Daily Water Usage Over One Week')
plt.xlabel('Date')
plt.ylabel('Water Usage (Liters)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### **Solution**

# %%
df = pd.DataFrame({
    'Date': pd.date_range(start='2023-07-01', periods=7, freq='D'),
    'Water_Usage_Liters': [180, 175, 190, 200, 195, 230, 250]
})

df['Date'] = pd.to_datetime(df['Date'])
plt.plot(df['Date'], df['Water_Usage_Liters'], marker='o')
plt.title('Daily Water Usage Over One Week')
plt.xlabel('Date')
plt.ylabel('Water Usage (Liters)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### **Problem #5.2**
#
# Use the dataset below to create a time series plot showing website visits over 10 days. On which day was traffic the highest?

# %%
df = pd.DataFrame({
    'Date': pd.date_range(start='2023-07-01', periods=10, freq='D'),
    'Website_Visits': [120, 135, 150, 160, 145, 140, 170, 180, 175, 160]
})

df['Date'] = pd.to_datetime(df['Date'])
plt.plot(df['Date'], df['Website_Visits'], marker='o')
plt.title('Website Visits Over 10 Days')
plt.xlabel('Date')
plt.ylabel('Number of Visits')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### **Solution**

# %%
df = pd.DataFrame({
    'Date': pd.date_range(start='2023-07-01', periods=7, freq='D'),
    'Water_Usage_Liters': [180, 175, 190, 200, 195, 230, 250]
})

df['Date'] = pd.to_datetime(df['Date'])
plt.plot(df['Date'], df['Water_Usage_Liters'], marker='o')
plt.title('Website Visits Over 10 Days')
plt.xlabel('Date')
plt.ylabel('Number of Visits')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ---
#
# # End of Notebook
#
# © 2025 The Coding School, All rights reserved
